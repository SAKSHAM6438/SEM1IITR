# %%
import numpy  as np
import warnings
warnings.filterwarnings("ignore")




csk=np.array([["mi",156,7,1],["mi",97,10,0],["mi",150,4,1],["mi",159,3,1],["mi",198,5,1],['kkr',131,5,0],['kkr',190,4,1],['kkr',141,3,1],['rcb',216,4,0],['rcb',176,5,1],['rcb',226,6,0],['rcb',182,4,1],['rcb',208,8,1],['rcb',199,7,0],['dc',208,6,0],['dc',167,8,0],['dc',171,6,1],['dc',158,7,1],['pb',126,10,1],['pb',176,6,1],['pb',189,8,1],['pb',167,9,0],['srh',154,7,0],['srh',202,2,0],['srh',138,3,1],['srh',170,6,0],['srh',207,4,0],['lsg',210,7,0],['lsg',217,7,0],['lsg',176,6,0],['lsg',210,10,0],['gt', 169, 5, 0],['gt', 133, 5, 0],['gt', 178, 7, 0],['gt', 157, 7, 1],['gt', 171, 5, 1],['gt', 213, 5, 1],['gt', 166, 4, 1],['rr', 173, 5, 1],['rr', 189, 4, 0],['rr', 175, 5, 1],['rr', 172, 6, 1],['rr', 160, 4, 1],['rr', 185, 7, 0]])
mi=np.array([["csk",155,7,0],["csk",103,5,1],["csk",149,6,0],["csk",157,8,0],["csk",178,10,0],
             ['rcb', 151, 6, 0],['rcb', 171, 7, 0],['rcb', 200, 4, 1],
    ['kkr', 161, 4, 1],
    ['kkr', 157, 7, 0],
    ['kkr', 180, 6, 1],
    ['rr', 179, 9, 0],  # csk rcb mi kkr dc pb lsg srh gt 
    ['rr', 200, 4, 1],
    ['rr', 188, 6, 0],
    ['rr', 183, 1, 1],
    ['pb', 186, 9, 0],
    ['pb', 213, 5, 1],
    ['pb', 201, 6, 0],
    ['dc', 160, 5, 1],
    ['dc', 160, 9, 0],
    ['dc', 172, 8, 1],
    ['dc', 159, 7, 0],
    ['lsg', 196, 6, 0],
    ['lsg', 214, 6, 1],
    ['gt', 177, 8, 1],
    ['gt', 172, 7, 1],
    ['gt', 233, 6, 0],
    ['gt', 171, 9, 1],
    ['srh', 173, 8, 1],
    ['srh', 201, 7, 0],
    ['srh', 277, 3, 0]])
dc=np.array([['csk',117,10,1],['csk',140,8,1],['csk',154,6,0],['csk',191,5,0],
    ['rcb', 164, 5, 0],
    ['rcb', 160, 7, 0],
    ['rcb', 200, 7, 1],
    ['mi', 159, 7, 1],
    ['mi', 160, 5, 0],
    ['mi', 172, 8, 0],
    ['mi', 160, 9, 1],
    ['kkr', 157, 3, 0],
    ['kkr', 179, 8, 1],
    ['kkr', 159, 6, 1],
    ['pb', 167, 7, 0],
    ['pb', 136, 8, 1],
    ['pb', 198, 8, 0],
    ['pb', 213, 2, 0],
    ['rr', 174, 6, 0],
    ['rr', 172, 5, 1],
    ['lsg', 150, 8, 0],
    ['lsg', 178, 7, 1],
    ['gt', 170, 4, 0],
    ['gt', 186, 4, 1],
    ['srh', 199, 9, 0],
    ['srh', 220, 8, 1],
    ['srh', 266, 7, 0]])
pb=np.array([['csk',180,6,0],['csk',187,4,0],['csk',201,7,0],['csk',139,9,1],
    ['rcb', 208, 5, 0],
    ['rcb', 205, 2, 1],
    ['kkr', 141, 4, 0],  
    ['kkr', 146, 7, 1],
    ['kkr', 200, 9, 1],
    ['dc', 174, 9, 0],
    ['dc', 161, 8, 1],
    ['dc', 173, 9, 1],
    ['dc', 168, 7, 1],
    ['mi', 192, 7, 0],
    ['mi', 214, 3, 1],
    ['mi', 160, 8, 1],
    ['mi', 170, 7, 0],
    ['mi', 180, 8, 1],
    ['rr', 189, 5, 0],
    ['rr', 182, 9, 1],
    ['rr', 200, 6, 1],
    ['rr', 160, 8, 1],
    ['rr', 157, 9, 1],
    ['lsg', 185, 8, 0],
    ['lsg', 160, 9, 1],
    ['lsg', 179, 7, 1],
    ['lsg', 160, 9, 1],
    ['lsg', 180, 6, 1],
    ['gt', 200, 6, 0],
    ['gt', 175, 8, 1],
    ['gt', 188, 7, 1],
    ['gt', 162, 9, 1],
    ['gt', 190, 7, 1],
    ['srh', 157, 8, 1],  
    ['srh', 160, 5, 0], 
    ['srh', 182, 6, 1]])
srh=np.array([['csk',155,2,1],['csk',189,6,1],['csk',134,7,0],['csk',172,4,1],['csk',129,10,1],
    ['rcb', 125, 7, 0],
    ['rcb', 192, 3, 0],
    ['rcb', 166, 9, 0],
    ['mi', 213, 6, 1],
    ['mi', 180, 5, 0],
    ['mi', 218, 7, 1],
    ['mi', 174, 3, 0],
    ['mi', 176, 5, 1],
    ['mi', 246, 5, 1],
    ['kkr', 177, 6, 1],
    ['kkr', 165, 6, 0],
    ['kkr', 165, 4, 0],
    ['dc', 171, 8, 0],
    ['dc', 137, 6, 1],
    ['dc', 199, 10, 1],
    ['pbks', 151, 10, 0],  
    ['pbks', 160, 5, 1],    
    ['pbks', 180, 6, 0],
    ['lsg', 157, 9, 1],
    ['lsg', 121, 8, 0],
    ['gt', 199, 5, 1],
    ['gt', 188, 9, 0],
    ['rr', 210, 6, 1],  # IPL 2022
    ['rr', 217, 6, 0],  # IPL 2023
])
lsg=np.array([['csk',211,4,1],['csk',205,7,1],['csk',180,2,1],['csk',211,4,1],
    ['rcb', 187, 7, 0],
    ['rcb', 160, 7, 1],
    ['mi', 214, 6, 0],
    ['mi', 196, 6, 1],
    ['kkr', 128, 7, 0],
    ['kkr', 185, 6, 1],
    ['kkr', 200, 9, 1],
    ['dc', 154, 6, 0],
    ['dc', 142, 8, 1],
    ['pb', 160, 7, 0],
    ['pb', 172, 8, 1],
    ['pb', 185, 6, 0],
    ['pb', 170, 7, 1],
    ['pb', 174, 6, 0],
    ['gt', 160, 6, 1],  
    ['gt', 171, 7, 0],  
    ['gt', 163, 5, 1],
    ['srh', 169, 7, 0],
    ['srh', 127, 5, 1],
    ['rr', 178, 8, 0],
    ['rr', 154, 8, 1]])
gt=np.array([['csk', 170, 7, 1],['csk', 137, 3, 1],['csk', 179, 4, 1],['csk', 154, 10, 0],['csk', 214, 4, 0],['csk', 212, 3, 0],['csk', 165, 6, 0],
    ['rcb', 174, 4, 0],
    ['rcb', 180, 9, 0],
    ['rcb', 191, 6, 1],
    ['mi', 176, 5, 0],
    ['mi', 177, 8, 0],
    ['mi', 185, 5, 1],
    ['mi', 169, 7, 0],
    ['kkr', 120, 5, 0],
    ['kkr', 155, 6, 1],
    ['kkr', 172, 4, 1],
    ['dc', 160, 8, 0],
    ['dc', 172, 9, 1],
    ['pb', 180, 7, 0],
    ['pb', 160, 9, 1],
    ['pb', 185, 8, 0],
    ['pb', 150, 9, 1],
    ['pb', 170, 6, 1],
    ['lsg', 158, 6, 0],
    ['lsg', 171, 7, 1],
    ['lsg', 163, 5, 0],
    ['srh', 195, 6, 0],
    ['srh', 154, 9, 1],
    ['rr', 193, 8, 0],
    ['rr', 178, 6, 1],
    ['rr', 196, 3, 0]])
rr=np.array([
    ['csk', 175, 5, 0],
    ['csk', 190, 4, 1],
    ['csk', 177, 6, 0],
    ['csk', 175, 7, 1],
    ['csk', 161, 6, 0],
    ['csk', 186, 5, 1],
    ['rcb', 165, 6, 1],
    ['rcb', 189, 10, 0],
    ['rcb', 170, 7, 0],
    ['mi', 179, 9, 1],
    ['mi', 210, 4, 0],
    ['mi', 170, 7, 1],
    ['mi', 180, 6, 0],
    ['kkr', 175, 7, 0],
    ['kkr', 185, 9, 1],
    ['kkr', 165, 9, 1],
    ['dc', 152, 8, 0],
    ['dc', 169, 9, 1],
    ['pb', 144, 7, 0],
    ['pb', 160, 6, 1],
    ['pb', 179, 5, 1],
    ['pb', 165, 8, 1],
    ['pb', 160, 9, 1],
    ['lsg', 154, 8, 1],
    ['lsg', 179, 7, 0],
    ['srh', 160, 9, 0],  
    ['srh', 150, 7, 1],
    ['gt', 192, 4, 1],
    ['gt', 181, 2, 0],
    ['gt', 199, 7, 1]])
rcb=np.array([
    ['mi', 152, 3, 1],
    ['mi', 172, 2, 1],
    ['mi', 196, 8, 0],['csk', 193, 9, 0],['csk', 218, 8, 0],['csk', 226, 6, 1],['csk',173,6,0],
    ['kkr', 130, 8, 1],
    ['kkr', 170, 4, 1],
    ['kkr', 205, 6, 0],
    ['gt', 170, 6, 1],
    ['gt', 182, 8, 1],
    ['gt', 189, 5, 0],
    ['lsg', 183, 8, 1],
    ['lsg', 161, 6, 0],
    ['rr', 155, 6, 1],
    ['rr', 189, 9, 0],
    ['rr', 172, 6, 1],
    ['pb', 205, 2, 0],
    ['pb', 208, 5, 1],
    ['dc', 173, 4, 1],
    ['dc', 157, 6, 1],
    ['dc', 151, 5, 0],
    ['srh', 192, 3, 0],
    ['srh', 125, 7, 1],
    ['srh', 166, 9, 1]])

kkr=np.array([
    ['rcb', 128, 6, 0],
    ['rcb', 186, 8, 0],
    ['rcb', 221, 7, 1],
    ['mi', 164, 5, 0],
    ['mi', 161, 6, 1],
    ['mi', 190, 4, 0],
    ['srh', 123, 8, 0],
    ['srh', 160, 7, 0],
    ['srh', 141, 6, 1],
    ['dc', 159, 6, 0],
    ['dc', 179, 8, 0],
    ['dc', 157, 3, 1],
    ['pb', 137, 4, 1],  
    ['pb', 191, 5, 0],  
    ['pb', 262, 6, 0],
    ['lsg', 120, 8, 0],
    ['lsg', 179, 5, 1],
    ['lsg', 198, 6, 0],
    ['gt', 145, 6, 1],
    ['gt', 183, 4, 1],
    ['gt', 201, 8, 0],
    ['csk', 235, 4, 0],
    ['csk', 186, 8, 1],
    ['csk', 141, 3, 1],
    ['rr', 194, 6, 0],
    ['rr', 207, 5, 1],
    ['rr', 173, 5, 1]])

csk_l=list(csk)

l=[csk,rcb,mi,gt,rr,pb,dc,kkr,lsg,srh]
ll=['csk','rcb','mi','gt','rr','pb','dc','kkr','lsg','srh']
ipl_slogans = [
    "Whistle Podu",
    "Play Bold",
    "Duniya Hila Denge",
    "Aava De",
    "Halla Bol",
     "Sadda Punjab"
    "This Is New Delhi",
    "Korbo Lorbo Jeetbo",
    "This Is New Delhi",
    "Ab Apni Bari Hai"
    "Rise Up to Every Challenge",
    "Ab Apni Bari Hai",]


print("enter in batting order i.e 1st batting team should be filled first")
print("enter team---->\n 0=csk\n 1=rcb\n 2=mi\n 3=gt\n 4=rr\n 5=pb \n 6=dc\n 7=kkr\n8=lsg\n 9=srh\n")
print()
print()
print()
ax=int(input('enter first team'))
print(f"SO FIRST TEAM IS {ll[ax]}")
#c=input("enter team name")
bx=int(input('enter second team'))
print(f" SECOND TEAM IS  {ll[bx]}")
l1=[]
l2=[]
for i in range(len(l)):
    if i==ax:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[bx]:
                
                
                if j[3]=='0':
                    l1.append(j[1])
l1n=[]
l2n=[]
for i in range(len(l)):
    if i==bx:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[ax]:
                
                
                if j[3]=='1':
        
                    l2.append(j[1])
                    
for i in l1:
    l1n.append(int(i))
for i in l2:
    l2n.append(int(i))
#print(l1n)
#print(l2n)
l11=[]
l22=[]
for i in range(len(l)):
    if i==ax:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[bx]:
                continue
                
                
            if j[3]=='0':
                l11.append(j[1])

for i in range(len(l)):
    if i==bx:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[ax]:
                continue
                
                
            if j[3]=='1':
                l22.append(j[1])
l11=np.array(l11)
l22=np.array(l22)
l11n=[]
l22n=[]
for i in l11:
    l11n.append(int(i))
for i in l22:
    l22n.append(int(i))
l11n=np.array(l11n)
l22n=np.array(l22n)
#print(l11n)
#print(l22n)
y1=np.linspace(1,len(l1n),len(l1n))
#print(y1)
y2=np.linspace(1,len(l11n),len(l11n))
y3=np.linspace(1,len(l2n),len(l2n))
y4=np.linspace(1,len(l22n),len(l22n))
#print(l11n)
#print(l1n)
q1=np.polyfit(y1,l1n,1)
q2=np.polyfit(y2,l11n,1)
q3=np.polyfit(y3,l2n,1)
q4=np.polyfit(y4,l22n,1)


a=len(l1n)+1
b=len(l11n)+1
c=len(l2n)+1
d=len(l22n)+1
a1=q1[0]*a +q1[1]
b1=q2[0]*b +q2[1]
c1=q3[0]*c + q3[1]
d1=q4[0]*d + q4[1]
##############################################################################
m1=[]
m2=[]

for i in range(len(l)):
    if i==ax:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[bx]:
                
                
                if j[3]=='0':
                    m1.append(j[2])
for i in range(len(l)):
    if i==bx:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[ax]:
                
                
                if j[3]=='1':
                    m2.append(j[2])
m1n=[]
m2n=[]
for i in m1:
    m1n.append(int(i))
for i in m2:
    m2n.append(int(i))
m11=[]
m22=[]
for i in range(len(l)):
    if i==ax:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[bx]:
                continue
                
                
            if j[3]=='0':
                m11.append(j[2])

for i in range(len(l)):
    if i==bx:
        
        d=l[i]
        for j in d:
            
            if j[0]==ll[ax]:
                continue
                
                
            if j[3]=='1':
                m22.append(j[2])
m11n=[]
m22n=[]
for i in m11:
    m11n.append(int(i))
for i in m22:
    m22n.append(int(i))
m11n=np.array(m11n)
m22n=np.array(m22n)
y11=np.linspace(1,len(m1n),len(m1n))

y22=np.linspace(1,len(m2n),len(m2n))
y33=np.linspace(1,len(m11n),len(m11n))
y44=np.linspace(1,len(m22n),len(m22n))
q11=np.polyfit(y11,m1n,1)
q22=np.polyfit(y33,m11n,1)
q33=np.polyfit(y22,m2n,1)
q44=np.polyfit(y44,m22n,1)


aa=len(l1n)+1
bb=len(l11n)+1
cc=len(l2n)+1
dd=len(l22n)+1
a11=q11[0]*aa +q11[1]
b11=q22[0]*bb +q22[1]
c11=q33[0]*cc + q33[1]
d11=q44[0]*dd + q44[1]

                
 
print('----------------------------------------------------------------------------------------------------------------------------------------------')
print('----------------------------------------------------------------------------------------------------------------------------------------------')
print(f'In first inning {ll[ax]} will probably score : ')
print(f' {int((0.6*a1)+(0.4*b1))}/{abs(int((0.6*a11)+(0.4*b11)))} ')
if int((0.6*c1)+(0.4*d1))-int((0.6*a1)+(0.4*b1)) <7:
    print(f'In second inning {ll[bx]} will probably score : ')
    print(f"{int((0.6*c1)+(0.4*d1))}/{int((0.6*c11)+(0.4*d11))}")
    if int((0.6*a1)+(0.4*b1))>int((0.6*c1)+(0.4*d1)):
       print(f"{ll[ax]} will win this match by {abs(int((0.6*a1)+(0.4*b1))-int((0.6*c1)+(0.4*d1)))} runs")
    else:
        print(f"{ll[bx]} will win this match by {10-abs((int((0.6*c11)+(0.4*d11))))} wickets")
    
else:
    print(f'In second inning {ll[bx]} will probably score : ')
    import random
    v=int((0.6*a1)+(0.4*b1))+random.randint(0,6)
    print(f' {v}/{int((0.6*c11)+(0.4*d11))} ')
    if int((0.6*a1)+(0.4*b1))>int(v):
        print(f"{ll[ax]} will win this match by {abs(int((0.6*a1)+(0.4*b1))-int((0.6*c1)+(0.4*d1)))} runs")
    elif  int((0.6*a1)+(0.4*b1))==int(v):
        print("tie")
    else:
        print(f"{ll[bx]} will win this match by {10-abs(int((0.6*c11)+(0.4*d11)))} wickets")
# Out:
# enter in batting order i.e 1st batting team should be filled first
# enter team---->
#  0=csk
#  1=rcb
#  2=mi
#  3=gt
#  4=rr
#  5=pb
#  6=dc
#  7=kkr
# 8=lsg
#  9=srh
# enter first team 0
# SO FIRST TEAM IS csk
# enter second team 1
#  SECOND TEAM IS  rcb
# ----------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------
# In first inning csk will probably score :
#  196/7
# In second inning rcb will probably score :
#  202/8
# rcb will win this match by 2 wickets
